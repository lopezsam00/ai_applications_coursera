# %%
import os
from dotenv import load_dotenv

# Load environment variables from .env file
load_dotenv()
OPENAI_API_KEY = os.getenv("OPENAI_API_KEY", "")
OPENAI_ORG_ID = os.getenv("OPENAI_ORG_ID", "")

# Model Configuration
DEFAULT_MODEL = os.getenv("DEFAULT_MODEL", "gpt-3.5-turbo")
TEMPERATURE = float(os.getenv("TEMPERATURE", "0.7"))
MAX_TOKENS = int(os.getenv("MAX_TOKENS", "500"))
WATSON_URL = os.getenv("IBM_URL_END_POINT")
PROJECT_ID = os.getenv("IBM_PROJECT_ID")
IBM_API_KEY = os.getenv("IBM_API_KEY")
TAVILY_KEY = os.getenv("TAVILY_API_KEY")
SERPER_API_KEY = os.getenv("SERPER_API_KEY")

# %%
# %pip install langchain==0.3.20 | tail -n 1
# %pip install crewai==0.141.0 | tail -n 1
# %pip install langchain-community==0.3.19 | tail -n 1
# %pip install langchain-openai==0.3.25 | tail -n 1
# %pip install duckduckgo-search==7.5.2 | tail -n 1
# %pip install crewai-tools==0.51.1 | tail -n 1
# %pip install databricks-sdk==0.46.0 | tail -n 1
# Out:
# Requirement already satisfied: jsonpointer>=1.9 in /home/samuel/Desktop/ai_applications_coursera/venv/lib/python3.12/site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.41->langchain==0.3.20) (3.0.0)
# Note: you may need to restart the kernel to use updated packages.
# WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7335b2ef92b0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/crewai/
# WARNING: Retrying (Retry(total=3, connect=None, read=None, redirect=None, status=None)) after connection broken by 'NewConnectionError('<pip._vendor.urllib3.connection.HTTPSConnection object at 0x7335b2e50f50>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution')': /simple/crewai/
# Successfully installed crewai-0.141.0 litellm-1.72.6
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: mypy-extensions>=0.3.0 in /home/samuel/Desktop/ai_applications_coursera/venv/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community==0.3.19) (1.1.0)
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# embedchain 0.1.128 requires langchain-openai<0.3.0,>=0.2.1, but you have langchain-openai 0.3.25 which is incompatible.
# Successfully installed langchain-openai-0.3.25
# Note: you may need to restart the kernel to use updated packages.
# Successfully installed duckduckgo-search-7.5.2 primp-1.2.2
# Note: you may need to restart the kernel to use updated packages.
# Successfully installed crewai-tools-0.51.1 langchain-openai-0.2.14
# Note: you may need to restart the kernel to use updated packages.
# Successfully installed databricks-sdk-0.46.0
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install litellm
import litellm
litellm.ssl_verify = False

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/3xGOgzMOv5jhRsA3A8N9fQ/leftover.py"
# Out:
# --2026-04-14 07:51:00--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/3xGOgzMOv5jhRsA3A8N9fQ/leftover.py
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 588 [application/x-python]
# Saving to: ‘leftover.py’
#
# leftover.py         100%[===================>]     588  --.-KB/s    in 0s
#
# 2026-04-14 07:51:02 (140 MB/s) - ‘leftover.py’ saved [588/588]

# %%
import sys
sys.path.append(".")

# %%
from leftover import LeftoversCrew

# %%
import os

files = os.listdir('.')
print(files)
# Out:
# ['19_reAct_agentic.ipynb', '10_dalle.ipynb', '16_lang_graph_101.ipynb', '05_similarity_search.ipynb', '11_image_captioning.ipynb', '14_tool_calling_agent.ipynb', '03_build_smarter_ai.ipynb', '12-llm_data_science.ipynb', '06_smarter_doc_search.ipynb', 'leftover.py', '07_advanced_retrievers_llamaindex.ipynb', '22_grocery_planner_crewai.ipynb', '15_pandas_with_agent.ipynb', '08_faiss_melvin.ipynb', '.ipynb_checkpoints', '09_text_to_speech.ipynb', '13_interactive_llm.ipynb', '20_work_pattern_agent.ipynb', '11-ai-math.ipynb', '02_in_context_learning.ipynb', '21_multi_agent_researcher_system.ipynb', '18_building_reflexion_agent.ipynb', '04_summarize_private_doc.ipynb', '17_reflective_agent.ipynb', '21_investment_multiple_agents_orchestration.ipynb', '__pycache__', '01_getting_started.ipynb']

# %%
from pydantic import BaseModel, Field
from typing import List, Dict, Optional
from IPython.display import display, JSON, Markdown
from datetime import datetime
import os

# %%
class GroceryItem(BaseModel):
    """Individual grocery item"""
    name: str = Field(description="Name of the grocery item")
    quantity: str = Field(description="Quantity needed (for example, '2 lbs', '1 gallon')")
    estimated_price: str = Field(description="Estimated price (for example, '$3-5')")
    category: str = Field(description="Store section (for example, 'Produce', 'Dairy')")

# %%
sample_item = GroceryItem(
    name="Chicken Breast",
    quantity="2 lbs",
    estimated_price="$8-12",
    category="Meat"
)

# %%
sample_item
# Out:
# GroceryItem(name='Chicken Breast', quantity='2 lbs', estimated_price='$8-12', category='Meat')

# %%
type(sample_item)
# Out:
# __main__.GroceryItem

# %%
# Display structured data
print("🛒 Sample Grocery Item Structure:")
display(JSON(sample_item.model_dump()))
# Out:
# 🛒 Sample Grocery Item Structure:

# %%
class MealPlan(BaseModel):
    """Simple meal plan"""
    meal_name: str = Field(description="Name of the meal")
    difficulty_level: str = Field(description="'Easy', 'Medium', 'Hard'")
    servings: int = Field(description="Number of people it serves")
    researched_ingredients: List[str] = Field(description="Ingredients found through research")

# %%
sample_meal = MealPlan(
    meal_name="Chicken Stir Fry",
    difficulty_level="Easy",
    servings=4,
    researched_ingredients=["chicken breast", "broccoli", "bell peppers", "garlic", "soy sauce", "rice"]
)

# %%
sample_meal
# Out:
# MealPlan(meal_name='Chicken Stir Fry', difficulty_level='Easy', servings=4, researched_ingredients=['chicken breast', 'broccoli', 'bell peppers', 'garlic', 'soy sauce', 'rice'])

# %%
print("\n🍽️ Sample Meal Plan Structure:")
display(JSON(sample_meal.model_dump()))
# Out:
# 🍽️ Sample Meal Plan Structure:

# %%
class ShoppingCategory(BaseModel):
    """Store section with items"""
    section_name: str = Field(description="Store section (for example, 'Produce', 'Dairy')")
    items: List[GroceryItem] = Field(description="Items in this section")
    estimated_total: str = Field(description="Estimated cost for this section")

# %%
sample_section = ShoppingCategory(
    section_name="Produce",
    items=[
        GroceryItem(name="Bell Peppers", quantity="3 pieces", estimated_price="$3-4", category="Produce"),
        GroceryItem(name="Onions", quantity="2 lbs", estimated_price="$2-3", category="Produce")
    ],
    estimated_total="$5-7"
)

# %%
print("\n🏪 Sample Shopping Section:")
display(JSON(sample_section.model_dump()))
# Out:
# 🏪 Sample Shopping Section:

# %%
class GroceryShoppingPlan(BaseModel):
    """Complete simplified shopping plan"""
    total_budget: str = Field(description="Total planned budget")
    meal_plans: List[MealPlan] = Field(description="Planned meals")
    shopping_sections: List[ShoppingCategory] = Field(description="Organized by store sections")
    shopping_tips: List[str] = Field(description="Money-saving and efficiency tips")

# %%
# %%capture
import os
from crewai_tools import SerperDevTool
from crewai import Agent, Task, Crew, Process
from crewai import LLM

# Set Watsonx environment variables
os.environ["WATSONX_API_BASE"] = "https://us-south.ml.cloud.ibm.com"
os.environ["WX_PROJECT_ID"] = PROJECT_ID

# Initialize LLM using Watsonx Granite
llm = LLM(
    model="openai/gpt-4o-mini",
    api_key=OPENAI_API_KEY,
    max_tokens=2000
)

# %%
# Set up search tool (you'll need to add your API key)
os.environ['SERPER_API_KEY'] = SERPER_API_KEY

# %%
meal_planner = Agent(
    role="Meal Planner & Recipe Researcher",
    goal="Search for optimal recipes and create detailed meal plans",
    backstory="A skilled meal planner who researches the best recipes online, considering dietary needs, cooking skill levels, and budget constraints.",
    tools=[SerperDevTool()],
    llm=llm,
    verbose=False
)

# %%
meal_planning_task = Task(
    description=(
        "Search for the best '{meal_name}' recipe for {servings} people within a {budget} budget. "
        "Consider dietary restrictions: {dietary_restrictions} and cooking skill level: {cooking_skill}. "
        "Find recipes that match the skill level and provide complete ingredient lists with quantities."
    ),
    expected_output="A detailed meal plan with researched ingredients, quantities, and cooking instructions appropriate for the skill level.",
    agent=meal_planner,
    output_pydantic=MealPlan,
    output_file="meals.json"
)

# %%
from crewai import Crew, Process

meal_planner_crew = Crew(
    agents=[meal_planner],
    tasks=[meal_planning_task],
    process=Process.sequential,  # Ensures tasks are executed in order
    verbose=True
)

meal_planner_result = meal_planner_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",                           
        "dietary_restrictions": ["no nuts"],       
        "cooking_skill": "beginner"                
    }
)
print("✅ Single meal planning completed!")
print("📋 Single Meal Results:")
print(meal_planner_result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 0053b9ec-d64b-4301-add3-d6d5998b3c15                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Chicken Stir Fry' recipe for 4 people within a $25 budget. Consider dietary         │
# │  restrictions: ['no nuts'] and cooking skill level: beginner. Find recipes that match the skill level and       │
# │  provide complete ingredient lists with quantities.                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: I need to find a Chicken Stir Fry recipe that meets the specified criteria: suitable for 4 people,    │
# │  within a $25 budget, without nuts, and appropriate for beginner cooks.                                         │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best Chicken Stir Fry recipe for 4 people under $25 no nuts beginner cook\"}"            │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best Chicken Stir Fry recipe for 4 people under $25 no nuts beginner cook',        │
# │  'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry Recipe - Mom    │
# │  On Timeout', 'link': 'https://www.momontimeout.com/easy-chicken-stir-fry-recipe/', 'snippet': 'This easy       │
# │  Chicken Stir Fry recipe is loaded with fresh veggies and the most delicious sauce made with honey, soy sauce,  │
# │  and toasted sesame oil!', 'position': 1}, {'title': 'Fast & Easy Chicken Stir Fry with Vegetables Recipe       │
# │  (nut-free)', 'link': 'https://nutfreewok.com/chicken-stir-fry-vegetables-recipe/', 'snippet': "I make a        │
# │  chicken stir fry when I want a healthy allergy friendly meal that's fast and easy. I used Foster Farms Simply  │
# │  Raised Boneless ...", 'position': 2}, {'title': 'Easiest Ever Chicken Stir Fry - Family Food on the Table',    │
# │  'link': 'https://www.familyfoodonthetable.com/easiest-ever-stir-fry/', 'snippet': 'This quick and easy         │
# │  chicken stir fry with veggies uses just a few ingredients and is perfect for a busy weeknight. No more         │
# │  takeout needed!', 'position': 3}, {'title': 'Easy Chicken Stir Fry Recipe - Small Town Woman', 'link':         │
# │  'https://www.smalltownwoman.com/easy-basic-chicken-stir-fry/', 'snippet': 'Chicken stir fry combines crispy    │
# │  chicken, broccoli, red bell pepper, onion, and snow peas in a savory ginger sauce with a hint of heat.',       │
# │  'position': 4}, {'title': 'Easy 5-star Chicken Stir Fry - Budget Bytes', 'link':                               │
# │  'https://www.budgetbytes.com/chicken-stir-fry/', 'snippet': 'This Chicken Stir Fry recipe is perfect for a     │
# │  quick & easy dinner. It has lots of chicken and veggies and a super delicious stir fry sauce!', 'position':    │
# │  5}, {'title': 'How to make the Best Quick and Easy Chicken Stir fry - YouTube', 'link':                        │
# │  'https://www.youtube.com/watch?v=Y2ECuBm8r_M', 'snippet': 'Get Full Recipe and List of Ingredients here        │
# │  https://cookingwithclaudy.com/black-pepper-chicken/ #chickenstirfry #stirfry #chicken.', 'position': 6},       │
# │  {'title': 'Easy Chicken Stir...                                                                                │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  Based on my search, I found a suitable recipe for a Chicken Stir Fry that meets all your specified criteria.   │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "meal_name": "Easy Chicken Stir Fry",                                                                        │
# │    "difficulty_level": "Beginner",                                                                              │
# │    "servings": 4,                                                                                               │
# │    "researched_ingredients": [                                                                                  │
# │      "1 lb boneless skinless chicken breasts, cut into bite-sized pieces",                                      │
# │      "2 tablespoons soy sauce",                                                                                 │
# │      "2 tablespoons olive oil",                                                                                 │
# │      "1 cup broccoli florets",                                                                                  │
# │      "1 cup bell peppers (any color), sliced",                                                                  │
# │      "1 cup carrots, julienned or sliced",                                                                      │
# │      "1 cup snap peas or snow peas",                                                                            │
# │      "2 cloves garlic, minced",                                                                                 │
# │      "1 teaspoon ground ginger (or 1 tablespoon fresh ginger, grated)",                                         │
# │      "2 tablespoons cornstarch",                                                                                │
# │      "1 tablespoon sesame oil",                                                                                 │
# │      "Salt and pepper to taste",                                                                                │
# │      "2 cups cooked rice (for serving)"                                                                         │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1b2804b8-ef6e-4396-b1e1-0a02f80be124                                                                     │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 0053b9ec-d64b-4301-add3-d6d5998b3c15                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: Based on my search, I found a suitable recipe for a Chicken Stir Fry that meets all your         │
# │  specified criteria.                                                                                            │
# │                                                                                                                 │
# │  {                                                                                                              │
# │    "meal_name": "Easy Chicken Stir Fry",                                                                        │
# │    "difficulty_level": "Beginner",                                                                              │
# │    "servings": 4,                                                                                               │
# │    "researched_ingredients": [                                                                                  │
# │      "1 lb boneless skinless chicken breasts, cut into bite-sized pieces",                                      │
# │      "2 tablespoons soy sauce",                                                                                 │
# │      "2 tablespoons olive oil",                                                                                 │
# │      "1 cup broccoli florets",                                                                                  │
# │      "1 cup bell peppers (any color), sliced",                                                                  │
# │      "1 cup carrots, julienned or sliced",                                                                      │
# │      "1 cup snap peas or snow peas",                                                                            │
# │      "2 cloves garlic, minced",                                                                                 │
# │      "1 teaspoon ground ginger (or 1 tablespoon fresh ginger, grated)",                                         │
# │      "2 tablespoons cornstarch",                                                                                │
# │      "1 tablespoon sesame oil",                                                                                 │
# │      "Salt and pepper to taste",                                                                                │
# │      "2 cups cooked rice (for serving)"                                                                         │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Single meal planning completed!
# 📋 Single Meal Results:
# meal_name='Easy Chicken Stir Fry' difficulty_level='Beginner' servings=4 researched_ingredients=['1 lb boneless skinless chicken breasts, cut into bite-sized pieces', '2 tablespoons soy sauce', '2 tablespoons olive oil', '1 cup broccoli florets', '1 cup bell peppers (any color), sliced', '1 cup carrots, julienned or sliced', '1 cup snap peas or snow peas', '2 cloves garlic, minced', '1 teaspoon ground ginger (or 1 tablespoon fresh ginger, grated)', '2 tablespoons cornstarch', '1 tablespoon sesame oil', 'Salt and pepper to taste', '2 cups cooked rice (for serving)']

# %%
shopping_organizer = Agent(
    role="Shopping Organizer", 
    goal="Organize grocery lists by store sections efficiently",
    backstory="An experienced shopper who knows how to organize lists for quick store trips and considers dietary restrictions.",
    tools=[],
    llm=llm,
    verbose=False
)

# %%
shopping_task = Task(
    description=(
        "Organize the ingredients from the '{meal_name}' meal plan into a grocery shopping list. "
        "Group items by store sections and estimate quantities for {servings} people. "
        "Consider dietary restrictions: {dietary_restrictions} and cooking skill: {cooking_skill}. "
        "Stay within budget: {budget}."
    ),
    expected_output="An organized shopping list grouped by store sections with quantities and prices.",
    agent=shopping_organizer,
    context=[meal_planning_task],
    output_pydantic=GroceryShoppingPlan,
    output_file="shopping_list.json"
)

# %%
two_agent_grocery_crew = Crew(
    agents=[meal_planner, shopping_organizer],  # Both agents
    tasks=[meal_planning_task, shopping_task],   # Both tasks
    process=Process.sequential,
    verbose=True
)

# Run the complete crew (this will do BOTH meal planning AND shopping)
shopping_result = two_agent_grocery_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",                           
        "dietary_restrictions": ["no nuts"],      
        "cooking_skill": "beginner"               
    }
)

# Print the shopping results
print("✅ Complete meal planning + shopping completed!")
print("📋 Shopping Results:")
print(shopping_result)
# Out:
# ╭──────────────────────────────────────────── Crew Execution Started ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Started                                                                                         │
# │  Name: crew                                                                                                     │
# │  ID: 4eba0ce1-2b2e-4f56-977d-63591a8fb559                                                                       │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Task: Search for the best 'Chicken Stir Fry' recipe for 4 people within a $25 budget. Consider dietary         │
# │  restrictions: ['no nuts'] and cooking skill level: beginner. Find recipes that match the skill level and       │
# │  provide complete ingredient lists with quantities.                                                             │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Action: Search the internet with Serper                                                               │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"best Chicken Stir Fry recipe for 4 people no nuts beginner cooking budget $25\"}"        │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'best Chicken Stir Fry recipe for 4 people no nuts beginner cooking budget $25',    │
# │  'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy Chicken Stir Fry | 20 Minute     │
# │  Meal - Olive Real Food', 'link': 'https://oliverealfood.com/easy-chicken-stir-fry-20-minute-meal/',            │
# │  'snippet': '... Nut-Free Granola · Homemade Granola Recipe Guide · Perfect Blueberry ... While the rice is     │
# │  cooking, dice your chicken and throw in the marinade ...', 'position': 1}, {'title': 'Fast & Easy Chicken      │
# │  Stir Fry with Vegetables Recipe (nut-free)', 'link':                                                           │
# │  'https://nutfreewok.com/chicken-stir-fry-vegetables-recipe/', 'snippet': 'This recipe is free of peanuts,      │
# │  tree nuts, egg, fish, shellfish, and milk as written. If allergic to wheat, be sure to use a gluten-free       │
# │  ...', 'position': 2}, {'title': 'Chicken Stir Fry - Wholesome Yum', 'link':                                    │
# │  'https://www.wholesomeyum.com/chicken-stir-fry/?srsltid=AfmBOoqRVhfo96HGMc-q6eiBAA6lqTm_VFeqxgfGIHFFBCT7NW9bh  │
# │  5lJ', 'snippet': 'Keto Nuts. Tools. Keto Cheat Sheets · Macro Calculator · Carb Calculator ... Chicken Stir    │
# │  Fry (Easy 30-Min Recipe) Recipe card; Serving Ideas ...', 'position': 3}, {'title': 'Easy 10 Minute Keto       │
# │  Chinese Chicken (Nut Free And Gluten Free)', 'link': 'https://www.youtube.com/watch?v=BVW0Jkf3n8c',            │
# │  'snippet': 'This video is designed to teach everyone how to make easy 10 minute keto Chinese chicken. This     │
# │  recipe is low carb, keto friendly, nut free, ...', 'position': 4}], 'relatedSearches': [{'query': 'Simple      │
# │  best chicken stir fry recipe for 4 people no nuts beginner cooking budget $25'}, {'query': 'Easy chicken stir  │
# │  fry sauce'}, {'query': 'Quick dinner ideas for 2'}, {'query': '15 minute chicken stir-fry'}, {'query': 'Quick  │
# │  dinner ideas for family'}, {'query': 'Lazy dinner ideas'}, {'query': 'Chicken stir fry recipe easy'},          │
# │  {'query': 'Simple chicken stir fry with vegetables'}], 'credits': 1}                                           │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Thought: I found several potential recipes for chicken stir fry that meet the dietary restrictions    │
# │  and budget. I will focus on the one that specifically mentions being nut-free and suitable for beginners, as   │
# │  well as providing a detailed ingredient list.                                                                  │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"Easy Chicken Stir Fry recipe for 4 people no nuts budget 25\"}"                          │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Easy Chicken Stir Fry recipe for 4 people no nuts budget 25', 'type': 'search',    │
# │  'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Easy 5-star Chicken Stir Fry - Budget Bytes', 'link':   │
# │  'https://www.budgetbytes.com/chicken-stir-fry/', 'snippet': "It's a simple mix of soy sauce, brown sugar,      │
# │  toasted sesame oil, minced garlic, grated ginger, cornstarch, water, and sriracha for a little kick ...",      │
# │  'position': 1}, {'title': 'Easiest Ever Chicken Stir Fry - Family Food on the Table', 'link':                  │
# │  'https://www.familyfoodonthetable.com/easiest-ever-stir-fry/', 'snippet': 'This quick and easy chicken stir    │
# │  fry with veggies uses just a few ingredients and is perfect for a busy weeknight. No more takeout needed!',    │
# │  'position': 2}, {'title': 'Easy Chicken Stir Fry Recipe - Mom On Timeout', 'link':                             │
# │  'https://www.momontimeout.com/easy-chicken-stir-fry-recipe/', 'snippet': 'This easy Chicken Stir Fry recipe    │
# │  is loaded with fresh veggies and the most delicious sauce made with honey, soy sauce, and toasted sesame       │
# │  oil!', 'position': 3}, {'title': 'Easy Chicken Stir Fry Recipe - Small Town Woman', 'link':                    │
# │  'https://www.smalltownwoman.com/easy-basic-chicken-stir-fry/', 'snippet': 'Basic Chicken Stir Fry is so quick  │
# │  to make using seasonal vegetables, an easy chicken marinade and a simple gravy adjusted to taste.',            │
# │  'position': 4}, {'title': 'Quick and Easy 15 Minute Chicken Stir-Fry - Oh Sweet Basil', 'link':                │
# │  'https://ohsweetbasil.com/quick-easy-15-minute-chicken-stir-fry-recipe/', 'snippet': 'This quick and easy      │
# │  15-minute chicken stir-fry is packed with flavor and crisp-tender veggies. A fast, healthy dinner perfect for  │
# │  busy ...', 'position': 5}, {'title': 'Easy chicken noodle stir fry recipe under 25 minutes - Facebook',        │
# │  'link': 'https://www.facebook.com/groups/199622854503979/posts/313860646413532/', 'snippet': "Hi all! Here is  │
# │  my chicken noodle stir fry recipe that's really **tasty** and very **easy to make**. It's budget-friendly,     │
# │  **healthy** and", 'position...                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────── 🔧 Agent Tool Execution ────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Thought: Thought: I found an appropriate recipe for Chicken Stir Fry that is beginner-friendly and meets       │
# │  dietary needs. I will compile the detailed ingredient list and cooking instructions suitable for 4 servings.   │
# │                                                                                                                 │
# │  Using Tool: Search the internet with Serper                                                                    │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Input ───────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  "{\"search_query\": \"Easy Chicken Stir Fry recipe ingredients cooking instructions for 4 servings no nuts\"}  │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ╭────────────────────────────────────────────────── Tool Output ──────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  {'searchParameters': {'q': 'Easy Chicken Stir Fry recipe ingredients cooking instructions for 4 servings no    │
# │  nuts', 'type': 'search', 'num': 10, 'engine': 'google'}, 'organic': [{'title': 'Fast & Easy Chicken Stir Fry   │
# │  with Vegetables Recipe (nut-free)', 'link': 'https://nutfreewok.com/chicken-stir-fry-vegetables-recipe/',      │
# │  'snippet': 'Instructions · Thinly slice chicken tenders across the grain and place into a medium mixing bowl.  │
# │  · Add 1 tablespoon soy sauce, michu, sugar, ...', 'position': 1}, {'title': 'Easy Chicken Stir Fry Recipe -    │
# │  Mom On Timeout', 'link': 'https://www.momontimeout.com/easy-chicken-stir-fry-recipe/', 'snippet':              │
# │  'Ingredients · 1 lb boneless, skinless chicken breast cut into 1 inch cubes · salt and pepper to taste · 2     │
# │  tbsp olive oil divided · 2 cups broccoli ...', 'position': 2}, {'title': 'Easiest Ever Chicken Stir Fry -      │
# │  Family Food on the Table', 'link': 'https://www.familyfoodonthetable.com/easiest-ever-stir-fry/', 'snippet':   │
# │  'Ingredients · 1 ¼ cups brown rice · 2 ½ cups water · 1 tablespoon canola oil, divided · 1 ½ pounds boneless   │
# │  skinless chicken breasts, cubed · salt ...', 'position': 3}, {'title': 'Easy Chicken Stir Fry - The Real Food  │
# │  Dietitians', 'link': 'https://therealfooddietitians.com/chicken-stir-fry/', 'snippet': "Sweet, savory, and     │
# │  tangy, this chicken stir fry is an easy recipe with a quick cook time. It's faster and more budget friendly    │
# │  than takeout.", 'position': 4}, {'title': 'Heat the olive oil in a large skillet or wok over medium ... -      │
# │  Facebook', 'link': 'https://www.facebook.com/groups/533302265732624/posts/573635758365941/', 'snippet':        │
# │  '*4-Ingredient Simple Chicken Stir-Fry* *Ingredients:* - 2 boneless, skinless chicken breasts (cut into        │
# │  strips) - 1 cup frozen mixed vegetables ( ...', 'position': 5}, {'title': 'Chicken Stir Fry Recipe (Better     │
# │  Than Takeout!) - YouTube', 'link': 'https://www.youtube.com/watch?v=lXpCuCVGwLY', 'snippet': 'This Easy        │
# │  Chicken Stir Fry Recipe is BETTER than takeout! Full recipe - https://eatingo...                               │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "meal_name": "Easy Chicken Stir Fry",                                                                        │
# │    "difficulty_level": "beginner",                                                                              │
# │    "servings": 4,                                                                                               │
# │    "researched_ingredients": [                                                                                  │
# │      "1 lb boneless, skinless chicken breast, cut into bite-sized pieces",                                      │
# │      "2 tablespoons vegetable oil (divided)",                                                                   │
# │      "2 cups mixed vegetables (broccoli, bell peppers, snap peas, carrots)",                                    │
# │      "2 teaspoons minced garlic",                                                                               │
# │      "1 teaspoon minced ginger",                                                                                │
# │      "1/4 cup low-sodium soy sauce",                                                                            │
# │      "2 tablespoons cornstarch",                                                                                │
# │      "1 tablespoon brown sugar",                                                                                │
# │      "1/4 cup chicken broth",                                                                                   │
# │      "Salt and pepper to taste",                                                                                │
# │      "Cooked rice, for serving"                                                                                 │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: 1b2804b8-ef6e-4396-b1e1-0a02f80be124                                                                     │
# │  Agent: Meal Planner & Recipe Researcher                                                                        │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭─────────────────────────────────────────────── 🤖 Agent Started ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Shopping Organizer                                                                                      │
# │                                                                                                                 │
# │  Task: Organize the ingredients from the 'Chicken Stir Fry' meal plan into a grocery shopping list. Group       │
# │  items by store sections and estimate quantities for 4 people. Consider dietary restrictions: ['no nuts'] and   │
# │  cooking skill: beginner. Stay within budget: $25.                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭───────────────────────────────────────────── ✅ Agent Final Answer ─────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Agent: Shopping Organizer                                                                                      │
# │                                                                                                                 │
# │  Final Answer:                                                                                                  │
# │  {                                                                                                              │
# │    "total_budget": "$25",                                                                                       │
# │    "meal_plans": [                                                                                              │
# │      {                                                                                                          │
# │        "meal_name": "Easy Chicken Stir Fry",                                                                    │
# │        "difficulty_level": "beginner",                                                                          │
# │        "servings": 4,                                                                                           │
# │        "researched_ingredients": [                                                                              │
# │          "1 lb boneless, skinless chicken breast, cut into bite-sized pieces",                                  │
# │          "2 tablespoons vegetable oil (divided)",                                                               │
# │          "2 cups mixed vegetables (broccoli, bell peppers, snap peas, carrots)",                                │
# │          "2 teaspoons minced garlic",                                                                           │
# │          "1 teaspoon minced ginger",                                                                            │
# │          "1/4 cup low-sodium soy sauce",                                                                        │
# │          "2 tablespoons cornstarch",                                                                            │
# │          "1 tablespoon brown sugar",                                                                            │
# │          "1/4 cup chicken broth",                                                                               │
# │          "Salt and pepper to taste",                                                                            │
# │          "Cooked rice, for serving"                                                                             │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "shopping_sections": [                                                                                       │
# │      {                                                                                                          │
# │        "section_name": "Protein",                                                                               │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Boneless, skinless chicken breast",                                                         │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$6.00",                                                                          │
# │            "category": "meat"                                                                                   │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$6.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Oils & Condiments",                                                                     │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Vegetable oil",                                                                             │
# │            "quantity": "1 bottle (16 oz)",                                                                      │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "oil"                                                                                    │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Low-sodium soy sauce",                                                                      │
# │            "quantity": "1 bottle (15 oz)",                                                                      │
# │            "estimated_price": "$2.50",                                                                          │
# │            "category": "condiment"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Brown sugar",                                                                               │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$1.50",                                                                          │
# │            "category": "sugar"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$7.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Vegetables",                                                                            │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Mixed vegetables (fresh or frozen)",                                                        │
# │            "quantity": "2 cups",                                                                                │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "vegetable"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Minced garlic",                                                                             │
# │            "quantity": "1 small jar (8 oz)",                                                                    │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "spice"                                                                                  │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Minced ginger",                                                                             │
# │            "quantity": "1 small jar (2 oz)",                                                                    │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "spice"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$7.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Baking & Grains",                                                                       │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Cornstarch",                                                                                │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$1.50",                                                                          │
# │            "category": "thickener"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Cooked rice",                                                                               │
# │            "quantity": "3 cups (pre-cooked or instant)",                                                        │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "grain"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$3.50"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Broths & Stocks",                                                                       │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Chicken broth",                                                                             │
# │            "quantity": "1 can (15 oz)",                                                                         │
# │            "estimated_price": "$1.00",                                                                          │
# │            "category": "broth"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$1.00"                                                                               │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "shopping_tips": [                                                                                           │
# │      "Buy frozen mixed vegetables to save time and possibly money.",                                            │
# │      "Check for sales on chicken and stock up if possible.",                                                    │
# │      "Opt for store-brand products for better savings.",                                                        │
# │      "Look for pre-minced garlic and ginger to ease preparation."                                               │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ╭──────────────────────────────────────────────── Task Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Task Completed                                                                                                 │
# │  Name: ebb15ae4-44b9-4525-8c77-c5a1cb7589ee                                                                     │
# │  Agent: Shopping Organizer                                                                                      │
# │  Tool Args:                                                                                                     │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ╭──────────────────────────────────────────────── Crew Completion ────────────────────────────────────────────────╮
# │                                                                                                                 │
# │  Crew Execution Completed                                                                                       │
# │  Name: crew                                                                                                     │
# │  ID: 4eba0ce1-2b2e-4f56-977d-63591a8fb559                                                                       │
# │  Tool Args:                                                                                                     │
# │  Final Output: {                                                                                                │
# │    "total_budget": "$25",                                                                                       │
# │    "meal_plans": [                                                                                              │
# │      {                                                                                                          │
# │        "meal_name": "Easy Chicken Stir Fry",                                                                    │
# │        "difficulty_level": "beginner",                                                                          │
# │        "servings": 4,                                                                                           │
# │        "researched_ingredients": [                                                                              │
# │          "1 lb boneless, skinless chicken breast, cut into bite-sized pieces",                                  │
# │          "2 tablespoons vegetable oil (divided)",                                                               │
# │          "2 cups mixed vegetables (broccoli, bell peppers, snap peas, carrots)",                                │
# │          "2 teaspoons minced garlic",                                                                           │
# │          "1 teaspoon minced ginger",                                                                            │
# │          "1/4 cup low-sodium soy sauce",                                                                        │
# │          "2 tablespoons cornstarch",                                                                            │
# │          "1 tablespoon brown sugar",                                                                            │
# │          "1/4 cup chicken broth",                                                                               │
# │          "Salt and pepper to taste",                                                                            │
# │          "Cooked rice, for serving"                                                                             │
# │        ]                                                                                                        │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "shopping_sections": [                                                                                       │
# │      {                                                                                                          │
# │        "section_name": "Protein",                                                                               │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Boneless, skinless chicken breast",                                                         │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$6.00",                                                                          │
# │            "category": "meat"                                                                                   │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$6.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Oils & Condiments",                                                                     │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Vegetable oil",                                                                             │
# │            "quantity": "1 bottle (16 oz)",                                                                      │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "oil"                                                                                    │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Low-sodium soy sauce",                                                                      │
# │            "quantity": "1 bottle (15 oz)",                                                                      │
# │            "estimated_price": "$2.50",                                                                          │
# │            "category": "condiment"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Brown sugar",                                                                               │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$1.50",                                                                          │
# │            "category": "sugar"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$7.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Vegetables",                                                                            │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Mixed vegetables (fresh or frozen)",                                                        │
# │            "quantity": "2 cups",                                                                                │
# │            "estimated_price": "$3.00",                                                                          │
# │            "category": "vegetable"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Minced garlic",                                                                             │
# │            "quantity": "1 small jar (8 oz)",                                                                    │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "spice"                                                                                  │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Minced ginger",                                                                             │
# │            "quantity": "1 small jar (2 oz)",                                                                    │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "spice"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$7.00"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Baking & Grains",                                                                       │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Cornstarch",                                                                                │
# │            "quantity": "1 lb",                                                                                  │
# │            "estimated_price": "$1.50",                                                                          │
# │            "category": "thickener"                                                                              │
# │          },                                                                                                     │
# │          {                                                                                                      │
# │            "name": "Cooked rice",                                                                               │
# │            "quantity": "3 cups (pre-cooked or instant)",                                                        │
# │            "estimated_price": "$2.00",                                                                          │
# │            "category": "grain"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$3.50"                                                                               │
# │      },                                                                                                         │
# │      {                                                                                                          │
# │        "section_name": "Broths & Stocks",                                                                       │
# │        "items": [                                                                                               │
# │          {                                                                                                      │
# │            "name": "Chicken broth",                                                                             │
# │            "quantity": "1 can (15 oz)",                                                                         │
# │            "estimated_price": "$1.00",                                                                          │
# │            "category": "broth"                                                                                  │
# │          }                                                                                                      │
# │        ],                                                                                                       │
# │        "estimated_total": "$1.00"                                                                               │
# │      }                                                                                                          │
# │    ],                                                                                                           │
# │    "shopping_tips": [                                                                                           │
# │      "Buy frozen mixed vegetables to save time and possibly money.",                                            │
# │      "Check for sales on chicken and stock up if possible.",                                                    │
# │      "Opt for store-brand products for better savings.",                                                        │
# │      "Look for pre-minced garlic and ginger to ease preparation."                                               │
# │    ]                                                                                                            │
# │  }                                                                                                              │
# │                                                                                                                 │
# │                                                                                                                 │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# ✅ Complete meal planning + shopping completed!
# 📋 Shopping Results:
# total_budget='$25' meal_plans=[MealPlan(meal_name='Easy Chicken Stir Fry', difficulty_level='beginner', servings=4, researched_ingredients=['1 lb boneless, skinless chicken breast, cut into bite-sized pieces', '2 tablespoons vegetable oil (divided)', '2 cups mixed vegetables (broccoli, bell peppers, snap peas, carrots)', '2 teaspoons minced garlic', '1 teaspoon minced ginger', '1/4 cup low-sodium soy sauce', '2 tablespoons cornstarch', '1 tablespoon brown sugar', '1/4 cup chicken broth', 'Salt and pepper to taste', 'Cooked rice, for serving'])] shopping_sections=[ShoppingCategory(section_name='Protein', items=[GroceryItem(name='Boneless, skinless chicken breast', quantity='1 lb', estimated_price='$6.00', category='meat')], estimated_total='$6.00'), ShoppingCategory(section_name='Oils & Condiments', items=[GroceryItem(name='Vegetable oil', quantity='1 bottle (16 oz)', estimated_price='$3.00', category='oil'), GroceryItem(name='Low-sodium soy sauce', quantity='1 bottle (15 oz)', estimated_price='$2.50', category='condiment'), GroceryItem(name='Brown sugar', quantity='1 lb', estimated_price='$1.50', category='sugar')], estimated_total='$7.00'), ShoppingCategory(section_name='Vegetables', items=[GroceryItem(name='Mixed vegetables (fresh or frozen)', quantity='2 cups', estimated_price='$3.00', category='vegetable'), GroceryItem(name='Minced garlic', quantity='1 small jar (8 oz)', estimated_price='$2.00', category='spice'), GroceryItem(name='Minced ginger', quantity='1 small jar (2 oz)', estimated_price='$2.00', category='spice')], estimated_total='$7.00'), ShoppingCategory(section_name='Baking & Grains', items=[GroceryItem(name='Cornstarch', quantity='1 lb', estimated_price='$1.50', category='thickener'), GroceryItem(name='Cooked rice', quantity='3 cups (pre-cooked or instant)', estimated_price='$2.00', category='grain')], estimated_total='$3.50'), ShoppingCategory(section_name='Broths & Stocks', items=[GroceryItem(name='Chicken broth', quantity='1 can (15 oz)', estimated_price='$1.00', category='broth')], estimated_total='$1.00')] shopping_tips=['Buy frozen mixed vegetables to save time and possibly money.', 'Check for sales on chicken and stock up if possible.', 'Opt for store-brand products for better savings.', 'Look for pre-minced garlic and ginger to ease preparation.']

# %%
budget_advisor = Agent(
    role="Budget Advisor",
    goal="Provide cost estimates and money-saving tips",
    backstory="A budget-conscious shopper who helps families save money on groceries while respecting dietary needs.",
    tools=[SerperDevTool()],
    llm=llm,
    verbose=False
)

# %%
budget_task = Task(
    description=(
        "Analyze the shopping plan for '{meal_name}' serving {servings} people. "
        "Ensure total cost stays within {budget}. Consider dietary restrictions: {dietary_restrictions}. "
        "Provide practical money-saving tips and alternative ingredients if needed to meet budget."
    ),
    expected_output="A complete shopping guide with detailed prices, budget analysis, and money-saving tips.",
    agent=budget_advisor,
    context=[meal_planning_task, shopping_task],
    output_file="shopping_guide.md"
)

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/-5NXnHGkX1WG81tqE8kSTg/agents.yaml"
# Out:
# --2026-04-14 08:08:59--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/-5NXnHGkX1WG81tqE8kSTg/agents.yaml
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)...
# /usr/lib/python3.12/pty.py:95: DeprecationWarning: This process (pid=546640) is multi-threaded, use of forkpty() may lead to deadlocks in the child.
#   pid, fd = os.forkpty()
# 198.23.119.245
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|198.23.119.245|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 337 [text/x-yaml]
# Saving to: ‘agents.yaml’
#
# agents.yaml         100%[===================>]     337  --.-KB/s    in 0s
#
# 2026-04-14 08:09:01 (211 MB/s) - ‘agents.yaml’ saved [337/337]

# %%
# !wget "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/7fhq1KPxi7cuqjOCBgcmXQ/tasks.yaml"
# Out:
# --2026-04-14 08:09:06--  https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/7fhq1KPxi7cuqjOCBgcmXQ/tasks.yaml
# Resolving cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)... 169.45.118.108
# Connecting to cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud (cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud)|169.45.118.108|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 517 [text/x-yaml]
# Saving to: ‘tasks.yaml’
#
# tasks.yaml          100%[===================>]     517  --.-KB/s    in 0s
#
# 2026-04-14 08:09:08 (205 MB/s) - ‘tasks.yaml’ saved [517/517]

# %%
from leftover import LeftoversCrew

leftovers_cb = LeftoversCrew(llm=llm)
yaml_leftover_manager = leftovers_cb.leftover_manager()
yaml_leftover_task    = leftovers_cb.leftover_task()

# %%
summary_agent = Agent(
    role="Report Compiler",
    goal="Compile comprehensive meal planning reports from all team outputs",
    backstory="A skilled coordinator who organizes information from multiple specialists into comprehensive, easy-to-follow reports.",
    tools=[],
    llm=llm,
    verbose=False
)

# %%
summary_task = Task(
    description=(
        "Compile a comprehensive meal planning report that includes:\n"
        "1. The complete recipe and cooking instructions from the meal planner\n"
        "2. The organized shopping list with prices from the shopping organizer\n"
        "3. The budget analysis and money-saving tips from the budget advisor\n"
        "4. The leftover management suggestions from the waste reduction specialist\n"
        "Format this as a complete, user-friendly meal planning guide."
    ),
    expected_output="A comprehensive meal planning guide that combines all team outputs into one cohesive report.",
    agent=summary_agent,
    context=[meal_planning_task, shopping_task, budget_task, yaml_leftover_task],
)

# %%
complete_grocery_crew = Crew(
    agents=[
        meal_planner,           
        shopping_organizer,      
        budget_advisor,         
        yaml_leftover_manager,  # YAML-based leftover manager
        summary_agent           # New summary agent
    ],
    tasks=[
        meal_planning_task,     
        shopping_task,          
        budget_task,            
        yaml_leftover_task,    # YAML-based leftover task
        summary_task            # New summary task
    ],
    process=Process.sequential,
    verbose=True
)

# %%
# Run the complete crew
complete_result = complete_grocery_crew.kickoff(
    inputs={
        "meal_name": "Chicken Stir Fry",
        "servings": 4,
        "budget": "$25",
        "dietary_restrictions": ["no nuts", "low sodium"],
        "cooking_skill": "beginner"
    }
)

print("✅ Complete meal planning with summary completed!")
print("📋 Complete Results:")
print(complete_result)
